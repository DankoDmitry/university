# %% [markdown]
# # Задание 4го семенара
#
# t = 200, r = 0,1  K = 1000
#
# N(0) = 10
#
# ![](Task.jpg)

# %% [markdown]
# # Занятие 4

# %%
from scipy.integrate import odeint

import matplotlib.pyplot as plt

# %matplotlib inline

import numpy as np

# %%
def pend(y, t, r, K):
    N = y
    dydt = r*N*(1-N/K)
    return dydt


r = 0.1
K = 1000

y0 = [10, 200, 700]

t = np.linspace(0, 200, 200)


from scipy.integrate import odeint
sol = odeint(pend, y0, t, args=(r, K))


analit = (y0[0] * np.e ** (r*t)) / (1 - y0[0]/K + (y0[0] * np.e ** (r*t)) / K)

def Xplicit_Y(y, tau, r, K, n0):
    if y == 0:
        return n0
    else:
        return (tau*r*y - tau*r*y*y/K + y)
m = [10]


for i in range(199):
    m.append(Xplicit_Y(m[i], 1, r, K, y0[0]))

# print(m)


plt.plot(m, 'g', label='plicit')
plt.plot(t, analit, 'b', label='analit')
plt.legend()
plt.show()
analit_arr = [analit]


abs_delta_y = 0
for i in range(199):
    abs_delta_y = max(abs(m[i] - analit[i]), abs_delta_y)
relativ_delta_y = max(abs(sol[:, 0] - analit)/analit)


print(f'abs_delta_y = {abs_delta_y} \nrelative_delta_y = {relativ_delta_y}')
# Out:
# abs_delta_y = 45.871374940848625
# relative_delta_y = 5.035263893213719e-08

# %% [markdown]
# ## Неявный метод Эйлера без Ньютона

# %%
def pend(y, t, r, K):
    N = y
    dydt = r*N*(1-N/K)
    return dydt


r = 0.1
K = 1000

y0 = [10, 200, 700]

t = np.linspace(0, 200, 2000)


from scipy.integrate import odeint
sol = odeint(pend, y0, t, args=(r, K))


analit = (y0[0] * np.e ** (r*t)) / (1 - y0[0]/K + (y0[0] * np.e ** (r*t)) / K)



def X_Implicit_Y(y, tau, r, K, n0):
    if y == 0:
        return n0
    else:
        b = K * (1-tau*r)/(tau*r)
        c = K/(tau*r)
        D = b**2 + y*4*c
        return (-b + np.sqrt(D))/2
m = [10]


for i in range(1999):
    m.append(X_Implicit_Y(m[i], 0.1, r, K, y0[0]))

# print(m)


plt.plot(t, m, 'g', label='implicit')
plt.plot(t, analit, 'b', label='analit')
plt.legend()
plt.show()
analit_arr = [analit[i] for i in range(1999)]

abs_delta_y = 0
for i in range(1999):
    abs_delta_y = max(abs(m[i] - analit[i]), abs_delta_y)
relativ_delta_y = max(abs(m - analit)/analit)


print(f'abs_delta_y = {abs_delta_y} \nrelative_delta_y = {relativ_delta_y}')
# Out:
# abs_delta_y = 3.4696621245929578
# relative_delta_y = 0.009927126745524812

# %% [markdown]
# ## Неявный метод Эйлера с Ньютоном

# %%
from scipy.integrate import odeint

import matplotlib.pyplot as plt

# %matplotlib notebook

import numpy as np

# %%
def pend(y, t, r, K):
    N = y
    dydt = r*N*(1-N/K)
    return dydt


r = 0.1
K = 1000

y0 = [10, 200, 700]

t = np.linspace(0, 200, 2000)


from scipy.integrate import odeint
sol = odeint(pend, y0, t, args=(r, K))

analit = (y0[0] * np.e ** (r*t)) / (1 - y0[0]/K + (y0[0] * np.e ** (r*t)) / K)










def X_Implicit_Y(y, tau, r, K, n0):
    if y == 0:
        return n0
    else:
        b = K * (1-tau*r)/(tau*r)
        c = K/(tau*r)
        D = b**2 + y*4*c
        return (-b + np.sqrt(D))/2
    

m = [10]


for i in range(1999):
    m.append(X_Implicit_Y(m[i], 0.1, r, K, y0[0]))

# print(m)













plt.plot(t, m, 'g', label='implicit')
plt.plot(t, analit, 'b', label='analit')
plt.legend()
plt.show()
analit_arr = [analit[i] for i in range(1999)]

abs_delta_y = 0
for i in range(1999):
    abs_delta_y = max(abs(m[i] - analit[i]), abs_delta_y)
relativ_delta_y = max(abs(m - analit)/analit)


print(f'abs_delta_y = {abs_delta_y} \nrelative_delta_y = {relativ_delta_y}')
# Out:
# <div id='c12f2847-cd6e-4690-9bcb-ee65fc5a1a5b'></div>
# abs_delta_y = 3.4696621245929578
# relative_delta_y = 0.009927126745524812
